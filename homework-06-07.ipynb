# %% [markdown]
# ## Интернет как отягчающее обстоятельство

# %% [markdown]
# **Экстремизм**
#
# Инициатор: Елена Мизулина
#
# *  https://www.pnp.ru/archive/2013/02/28/internet-kak-otyagchayushhee-obstoyatelstvo.html
#
# **Наркотрафик**
#
# * **РФ** УК РФ 228.1 ч. 2 (б) *Сбыт наркотических средств, психотропных веществ или их аналогов, совершенный  использованием средств массовой информации либо электронных или информационно-телекоммуникационных сетей (включая сеть "Интернет")*

# %% [markdown]
# ## Дела расследованные с помощью СОРМ
#
# Публичных официальных данные не найдено.

# %% [markdown]
# ## Темы обсуждавшиеся на Russian IGF
#
# см igf-ru.ipynb

# %% [markdown]
# ## Изменения собственности вокруг основных акторов IG в России
#
# Вопрос требует уточнения целей и методологии.
#
# * Отследить изменения в собственниках организаций принимавших участие в IGF?
# * Отследить судьбу участников IGF?

# %% [markdown]
# ## Деятельность РФ в области IGF
#
# Активная деятельность РФ в прогрессе международной сети Интернет:
#
# --//--//--
#
# Деятельность РФ в регулировании собственного сегмента:
#
# * Стандарты криптографии (https://www.rbc.ru/technology_and_media/24/06/2019/5d0cfea79a7947d12026629f)
# * Data Collection (Пакет Яровой)
